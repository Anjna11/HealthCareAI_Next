# %%
import ai
import json
import importlib
importlib.reload(ai)
# Out:
# <module 'ai' from '/mnt/anjna/workspace/Workspace/HealthCareAI_Next/HealthCareAI_API/ai.py'>

# %%
query_ls = [
    "add patient of roman reings?",
    "new patient of roman reings?",
    "new patient of roman?",
    "edit patiend of #123434343 to roman.",

    "delete patient 68ff451e3bc5e323bcee935f",

    "update patient anjna jagatiya",
    "update patient anjna 20",

    "Add appointment for patient id 68f9e0e2c0733c15797a68fc on 2025-10-30 for dental checkup",
]

for q in query_ls:
    print("Input:", q)
    result = ai.get_compilation(q)
    print("Result:", json.dumps(result, indent=4))
# Out:
# Input: add patient of roman reings?
# Result: {
#     "reseaoning": "User is requesting to add a new patient with the name Roman Reigns.",
#     "action": "add_patient",
#     "pid": "",
#     "name": {
#         "fname": "roman",
#         "lname": "reings"
#     },
#     "age": null,
#     "appointment": {}
# }
# Input: new patient of roman reings?
# Result: {
#     "reseaoning": "The user is asking to add a new patient with the name Roman Reings.",
#     "action": "add_patient",
#     "pid": "",
#     "name": {
#         "fname": "Roman",
#         "lname": "Reigns"
#     },
#     "age": null,
#     "appointment": {}
# }
# Input: new patient of roman?
# Result: {
#     "reseaoning": "User is asking to add a new patient with the name 'Roman'.",
#     "action": "add_patient",
#     "pid": "",
#     "name": {
#         "fname": "Roman",
#         "lname": ""
#     },
#     "age": null,
#     "appointment": {}
# }
# Input: edit patiend of #123434343 to roman.
# Result: {
# ...

# %%
action = result['action']
if action == 'add_patient':
    print({
      'name' : result['name'],
      "age" : result['age']
    })
    print("Updating of user")
# Out:
# {'name': {'fname': 'roman', 'lname': 'reings'}, 'age': 0}
# Updating of user

# %%
Add a patient named Chris Hemsworth. He is 30 years old.
Update patient 24, Chris Evans.
Add an appointment for patient ID 24 on 2025-10-30 for a dental checkup.
delete patient 24
